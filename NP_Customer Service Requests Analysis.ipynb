# %%
import pandas as pd
import numpy as np
dataset=pd.read_csv('Project 6.csv',low_memory=False)
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.shape
# Out:
# (364558, 53)

# %%
dataset.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# ...

# %%
dataset.tail()
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 364553    29609918  01/01/2015 12:04:44 AM  01/01/2015 10:22:31 AM   NYPD
# 364554    29608392  01/01/2015 12:04:28 AM  01/01/2015 02:25:02 AM   NYPD
# 364555    29607589  01/01/2015 12:01:30 AM  01/01/2015 12:20:33 AM   NYPD
# 364556    29610889  01/01/2015 12:01:29 AM  01/01/2015 02:42:22 AM   NYPD
# 364557    29611816  01/01/2015 12:00:50 AM  01/01/2015 02:47:50 AM   NYPD
#
#                             Agency Name           Complaint Type  \
# 364553  New York City Police Department          Illegal Parking
# 364554  New York City Police Department          Noise - Vehicle
# 364555  New York City Police Department  Noise - Street/Sidewalk
# 364556  New York City Police Department         Blocked Driveway
# 364557  New York City Police Department         Blocked Driveway
#
#               Descriptor    Location Type  Incident Zip      Incident Address  \
# ...

# %%
dataset_1.describe()
# Out:
#          Unique Key   Incident Zip  X Coordinate (State Plane)  \
# count  3.645580e+05  361560.000000                3.605280e+05
# mean   3.106595e+07   10858.496659                1.005043e+06
# std    7.331531e+05     578.263114                2.196362e+04
# min    2.960737e+07      83.000000                9.133570e+05
# 25%    3.049938e+07   10314.000000                9.919460e+05
# 50%    3.108795e+07   11209.000000                1.003470e+06
# 75%    3.167433e+07   11238.000000                1.019134e+06
# max    3.231065e+07   11697.000000                1.067186e+06
#
#        Y Coordinate (State Plane)  School or Citywide Complaint  Vehicle Type  \
# count               360528.000000                           0.0           0.0
# mean                203425.305782                           NaN           NaN
# std                  29842.192857                           NaN           NaN
# min                 121185.000000                           NaN           NaN
# ...

# %%
dataset.isna().sum()
# Out:
# Unique Key                             0
# Created Date                           0
# Closed Date                         2381
# Agency                                 0
# Agency Name                            0
# Complaint Type                         0
# Descriptor                          6501
# Location Type                        133
# Incident Zip                        2998
# Incident Address                   51699
# Street Name                        51699
# Cross Street 1                     57188
# Cross Street 2                     57805
# Intersection Street 1             313438
# Intersection Street 2             314046
# Address Type                        3252
# City                                2997
# Landmark                          364183
# Facility Type                       2389
# Status                                 0
# Due Date                               3
# Resolution Description                 0
# Resolution Action Updated Date      2402
# ...

# %%
dataset['City'].isna().sum()
# Out:
# 2997

# %%
dataset['City'].dropna(inplace=True)

# %%
dataset['City'].isna().sum()
# Out:
# 0

# %%
dataset['City'].nunique()
# Out:
# 53

# %%
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [15, 7.5]
plt.rcParams["figure.autolayout"] = True
fig,ax = plt.subplots()
dataset['City'].value_counts().plot(ax=ax, kind='bar', xlabel='Cities', ylabel='Complaints')
plt.show()

# %%
dataset['Complaint Type'].nunique()
brook=dataset.groupby('City').nunique()
brook

# %%
dataset.columns
brooklyn=dataset[dataset['City'] == 'BROOKLYN']
brooklyn
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 5         32306554  12/31/2015 11:56:30 PM  01/01/2016 01:50:11 AM   NYPD
# 9         32308391  12/31/2015 11:53:58 PM  01/01/2016 01:17:40 AM   NYPD
# 13        32305074  12/31/2015 11:47:58 PM  01/01/2016 08:18:47 AM   NYPD
# 17        32310273  12/31/2015 11:44:52 PM  01/01/2016 12:36:10 AM   NYPD
# 18        32306617  12/31/2015 11:40:59 PM  01/01/2016 02:37:28 AM   NYPD
# ...            ...                     ...                     ...    ...
# 364539    29608505  01/01/2015 12:23:55 AM  01/01/2015 02:58:38 AM   NYPD
# 364541    29612697  01/01/2015 12:19:22 AM  01/01/2015 02:41:10 AM   NYPD
# 364544    29613295  01/01/2015 12:17:48 AM  01/01/2015 03:24:48 AM   NYPD
# 364545    29613456  01/01/2015 12:17:47 AM  01/01/2015 12:51:13 AM   NYPD
# 364546    29613402  01/01/2015 12:15:45 AM  01/01/2015 02:04:54 AM   NYPD
#
#                             Agency Name      Complaint Type  \
# ...

# %%
brooklyn.columns
brooklyn.drop(['Agency', 'Agency Name',
       'Descriptor', 'Location Type',
       'Street Name', 'Cross Street 1', 'Cross Street 2',
       'Intersection Street 1', 'Intersection Street 2', 'Address Type',
      'Landmark', 'Facility Type', 'Status', 'Due Date',
       'Resolution Description', 'Resolution Action Updated Date',
       'Community Board', 'Borough', 'X Coordinate (State Plane)',
       'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough',
       'School Name', 'School Number', 'School Region', 'School Code',
       'School Phone Number', 'School Address', 'School City', 'School State',
       'School Zip', 'School Not Found', 'School or Citywide Complaint',
       'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
       'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
       'Bridge Highway Segment', 'Garage Lot Name', 'Ferry Direction',
       'Ferry Terminal Name', 'Latitude', 'Longitude'], axis=1)
# Out:
#         Unique Key            Created Date             Closed Date  \
# 5         32306554  12/31/2015 11:56:30 PM  01/01/2016 01:50:11 AM
# 9         32308391  12/31/2015 11:53:58 PM  01/01/2016 01:17:40 AM
# 13        32305074  12/31/2015 11:47:58 PM  01/01/2016 08:18:47 AM
# 17        32310273  12/31/2015 11:44:52 PM  01/01/2016 12:36:10 AM
# 18        32306617  12/31/2015 11:40:59 PM  01/01/2016 02:37:28 AM
# ...            ...                     ...                     ...
# 364539    29608505  01/01/2015 12:23:55 AM  01/01/2015 02:58:38 AM
# 364541    29612697  01/01/2015 12:19:22 AM  01/01/2015 02:41:10 AM
# 364544    29613295  01/01/2015 12:17:48 AM  01/01/2015 03:24:48 AM
# 364545    29613456  01/01/2015 12:17:47 AM  01/01/2015 12:51:13 AM
# 364546    29613402  01/01/2015 12:15:45 AM  01/01/2015 02:04:54 AM
#
#             Complaint Type  Incident Zip      Incident Address      City  \
# 5          Illegal Parking       11215.0         260 21 STREET  BROOKLYN
# ...

# %%
Brooklyn_SC_Plot=brooklyn[['Complaint Type','Incident Zip']].groupby(['Complaint Type','Incident Zip']).size().reset_index()

# %%
Brooklyn_SC_Plot
Brooklyn_SC_Plot.rename(columns={0:'Complaint counts'},inplace=True)
Brooklyn_SC_Plot

# %%
f, ax = plt.subplots(figsize=(20, 10))
sns.scatterplot(data = Brooklyn_SC_Plot, x='Incident Zip', y= 'Complaint Type',hue='Complaint counts',ax=ax)
ax.set_title('Complaint concentration on Brooklyn city')
plt.xlim(11201,11260)
# Out:
# (11201.0, 11260.0)

# %%
import matplotlib.pyplot as plt


Brooklyn_HB_Plot=brooklyn[['Complaint Type','Incident Zip']].groupby(['Incident Zip']).size().reset_index()
Brooklyn_HB_Plot

Brooklyn_HB_Plot.rename(columns={0:'Complaint counts'},inplace=True)
Brooklyn_HB_Plot

# %%
f, ax = plt.subplots(figsize=(20, 25))
plt.hexbin(x= Brooklyn_HB_Plot['Incident Zip'], y= Brooklyn_HB_Plot['Complaint counts'], gridsize = 200, cmap ='Reds')
ax.set_title('Complaint concentration on Brooklyn city')
plt.xlim(11201,11260)
plt.ylim(1000,5000)
ax.set_xlabel("Incident Zip", alpha=1)
ax.set_ylabel("Complaint Counts", alpha=1)
# Out:
# Text(0, 0.5, 'Complaint Counts')

# %%
datasetcc=dataset.groupby(['Complaint Type']).size().reset_index()
datasetcc
datasetcc.rename(columns={0:'Counts of complaint types'}, inplace=True)
datasetcc

# %%
plt.rcParams["figure.figsize"] = [15, 10]
plt.rcParams["figure.autolayout"] = True
fig,ax = plt.subplots()
sns.barplot(x=datasetcc['Counts of complaint types'],y=datasetcc['Complaint Type'],ax=ax,)
plt.show()

# %%
datasetcc

# %%
datasetcc.nlargest(10,['Counts of complaint types'])
# Out:
#              Complaint Type  Counts of complaint types
# 4          Blocked Driveway                     100881
# 12          Illegal Parking                      92679
# 16  Noise - Street/Sidewalk                      51692
# 13       Noise - Commercial                      44109
# 5          Derelict Vehicle                      21661
# 17          Noise - Vehicle                      19352
# 1              Animal Abuse                      10541
# 21                  Traffic                       5198
# 10      Homeless Encampment                       4879
# 23                  Vending                       4192

# %%
dataset_2=dataset[['City','Complaint Type']]

# %%
dataset_2.head()

# %%
dataset_2.to_csv('City and Complaints type.csv', index=False)

# %%
majorcom=dataset[['Complaint Type','City']].groupby(['City','Complaint Type']).size().reset_index()
majorcom
majorcom.rename(columns={0:'Major complaints'})
# Out:
#          City           Complaint Type  Major complaints
# 0     ARVERNE             Animal Abuse                46
# 1     ARVERNE         Blocked Driveway                52
# 2     ARVERNE         Derelict Vehicle                32
# 3     ARVERNE         Disorderly Youth                 2
# 4     ARVERNE                 Drinking                 1
# ..        ...                      ...               ...
# 783  Woodside         Blocked Driveway                28
# 784  Woodside         Derelict Vehicle                 8
# 785  Woodside          Illegal Parking               125
# 786  Woodside       Noise - Commercial                 2
# 787  Woodside  Noise - Street/Sidewalk                 5
#
# [788 rows x 3 columns]

# %%
sns.swarmplot( data = majorcom,y = 'City',x = 'Complaint Type')

# f, ax = plt.subplots(figsize=(25, 15))
# sns.scatterplot(data = majorcom, x='Complaint Type', y= 'City',ax=ax)
# ax.set_title('Major Complaints on city wise')
# plt.show()

# plt.rcParams["figure.figsize"] = [15, 10]
# plt.rcParams["figure.autolayout"] = True
# fig,ax = plt.subplots()
# sns.barplot(y=dataset_1['City'],x=datasetcc['Complaint Type'],ax=ax,)
# plt.show()
# Out:
# <AxesSubplot:xlabel='Complaint Type', ylabel='City'>

# %%
import datetime
from datetime import datetime

dataset['Created Date']=pd.to_datetime(dataset['Created Date'])
dataset['Closed Date']=pd.to_datetime(dataset['Closed Date'])
dataset_response=dataset[['Complaint Type','Created Date','Closed Date']]

# %%
dataset_response.head(10)
# Out:
#             Complaint Type        Created Date         Closed Date
# 0  Noise - Street/Sidewalk 2015-12-31 23:59:45 2016-01-01 00:55:15
# 1         Blocked Driveway 2015-12-31 23:59:44 2016-01-01 01:26:57
# 2         Blocked Driveway 2015-12-31 23:59:29 2016-01-01 04:51:03
# 3          Illegal Parking 2015-12-31 23:57:46 2016-01-01 07:43:13
# 4          Illegal Parking 2015-12-31 23:56:58 2016-01-01 03:24:42
# 5          Illegal Parking 2015-12-31 23:56:30 2016-01-01 01:50:11
# 6          Illegal Parking 2015-12-31 23:55:32 2016-01-01 01:53:54
# 7         Blocked Driveway 2015-12-31 23:54:05 2016-01-01 01:42:54
# 8          Illegal Parking 2015-12-31 23:53:58 2016-01-01 08:27:32
# 9         Blocked Driveway 2015-12-31 23:53:58 2016-01-01 01:17:40

# %%
dataset_response['Response time']=dataset_response['Closed Date']-dataset_response['Created Date']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12804\243037124.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_response['Response time']=dataset_response['Closed Date']-dataset_response['Created Date']

# %%
dataset_response.head()
# Out:
#             Complaint Type        Created Date         Closed Date  \
# 0  Noise - Street/Sidewalk 2015-12-31 23:59:45 2016-01-01 00:55:15
# 1         Blocked Driveway 2015-12-31 23:59:44 2016-01-01 01:26:57
# 2         Blocked Driveway 2015-12-31 23:59:29 2016-01-01 04:51:03
# 3          Illegal Parking 2015-12-31 23:57:46 2016-01-01 07:43:13
# 4          Illegal Parking 2015-12-31 23:56:58 2016-01-01 03:24:42
#
#     Response time
# 0 0 days 00:55:30
# 1 0 days 01:27:13
# 2 0 days 04:51:34
# 3 0 days 07:45:27
# 4 0 days 03:27:44

# %%
type(dataset_response['Response time'])
# datetime_obj = datetime.strptime(dataset_response['Response time'],"%d%b%Y%H%M%S")
# time_hour = dataset_response['Response time'].time()
# Out:
# pandas.core.series.Series

# %%
dataset_response['CL time'] = pd.to_datetime(dataset_response['Closed Date']).dt.time
dataset_response['CR time'] = pd.to_datetime(dataset_response['Created Date']).dt.time
# dataset_response['Response ex time']=dataset_response['CL time']-dataset_response['CR time']
# dataset_response['Response time']=pd.datetime.strptime(dataset_response['Response time'],"%d%b%Y %H:%M:%S").hour
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12804\3474363236.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_response['CL time'] = pd.to_datetime(dataset_response['Closed Date']).dt.time
# C:\Users\HP\AppData\Local\Temp\ipykernel_12804\3474363236.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_response['CR time'] = pd.to_datetime(dataset_response['Created Date']).dt.time

# %%
# dataset_response['Response time']=dataset_response['CL time']-dataset_response['CR time']

# %%
dataset_response.head()
# Out:
#             Complaint Type        Created Date         Closed Date  \
# 0  Noise - Street/Sidewalk 2015-12-31 23:59:45 2016-01-01 00:55:15
# 1         Blocked Driveway 2015-12-31 23:59:44 2016-01-01 01:26:57
# 2         Blocked Driveway 2015-12-31 23:59:29 2016-01-01 04:51:03
# 3          Illegal Parking 2015-12-31 23:57:46 2016-01-01 07:43:13
# 4          Illegal Parking 2015-12-31 23:56:58 2016-01-01 03:24:42
#
#     Response time   CL time   CR time
# 0 0 days 00:55:30  00:55:15  23:59:45
# 1 0 days 01:27:13  01:26:57  23:59:44
# 2 0 days 04:51:34  04:51:03  23:59:29
# 3 0 days 07:45:27  07:43:13  23:57:46
# 4 0 days 03:27:44  03:24:42  23:56:58

# %%
dataset_response['Response Time in Hours']=np.around( (dataset_response['Response time'].astype(np.int64)/(pow(10,9)*3600) ), decimals=2)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12804\586075831.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_response['Response Time in Hours']=np.around( (dataset_response['Response time'].astype(np.int64)/(pow(10,9)*3600) ), decimals=2)

# %%
dataset_response
dataset_response_1=dataset_response.groupby('Complaint Type').nunique().reset_index()
dataset_response_1
# Out:
#                Complaint Type  Created Date  Closed Date  Response time  \
# 0               Agency Issues             8            8              8
# 1                Animal Abuse         10527        10465           9066
# 2            Animal in a Park             1            1              1
# 3   Bike/Roller/Skate Chronic           475          474            472
# 4            Blocked Driveway        100431        98271          36994
# 5            Derelict Vehicle         21508        21291          17030
# 6            Disorderly Youth           315          314            314
# 7                    Drinking          1404         1398           1364
# 8                    Graffiti           157          157            157
# 9         Homeless Encampment          4878         4858           4508
# 10          Illegal Fireworks           172          172            172
# 11            Illegal Parking         91560        89622          35180
# ...

# %%
dataset_response.isna().sum()
dataset_response.dropna(inplace=True)
Avg_response_time=dataset_response[['Complaint Type','Response Time in Hours']].groupby(['Complaint Type']).mean().reset_index()

# %%
# Avg_response_time['Response Time in Hours']=np.around(Avg_response_time['Response Time in Hours'].astype(np.float64),decimals=2)

# %%
Avg_response_time=Avg_response_time.rename(columns={'Response Time in Hours':'Average Time in Hours'}).reset_index()

# %%
Avg_response_time_hours=Avg_response_time.drop('index',axis=1)

# %%
Avg_response_time_hours
# Out:
#                Complaint Type  Average Time in Hours
# 0               Agency Issues               5.078750
# 1                Animal Abuse               5.009000
# 2   Bike/Roller/Skate Chronic               3.645558
# 3            Blocked Driveway               4.509031
# 4            Derelict Vehicle               7.044364
# 5            Disorderly Youth               3.434698
# 6                    Drinking               3.839266
# 7                    Graffiti               6.465669
# 8         Homeless Encampment               4.292050
# 9           Illegal Fireworks               2.809186
# 10            Illegal Parking               4.347338
# 11         Noise - Commercial               3.079376
# 12   Noise - House of Worship               3.164279
# 13               Noise - Park               3.396126
# 14    Noise - Street/Sidewalk               3.397577
# 15            Noise - Vehicle               3.489395
# 16                Panhandling               4.403723
# ...
